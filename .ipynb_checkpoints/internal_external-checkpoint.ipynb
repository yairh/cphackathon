# %%
from ipwhois import IPWhois, IPDefinedError
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %%
obj = IPWhois('64.56.83.238')
results = obj.lookup_rdap()
print(results)
# Out:
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/net.py:138: UserWarning: allow_permutations has been deprecated and will be removed. It is no longer needed, due to the deprecation of asn_alts, and the addition of the asn_methods argument.
#   warn('allow_permutations has been deprecated and will be removed. '
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/asn.py:178: UserWarning: IPASN._parse_fields_dns() has been deprecated and will be removed. You should now use IPASN.parse_fields_dns().
#   warn('IPASN._parse_fields_dns() has been deprecated and will be '
# {'nir': None, 'asn_registry': 'arin', 'asn': '11096', 'asn_cidr': '64.56.83.0/24', 'asn_country_code': 'US', 'asn_date': '2006-05-31', 'asn_description': 'FLORIDANET - FloridaNet, US', 'query': '64.56.83.238', 'network': {'handle': 'NET-64-56-83-0-1', 'status': None, 'remarks': None, 'notices': [{'title': 'Terms of Service', 'description': 'By using the ARIN RDAP/Whois service, you are agreeing to the RDAP/Whois Terms of Use', 'links': ['https://www.arin.net/whois_tou.html']}, {'title': 'Whois Inaccuracy Reporting', 'description': 'If you see inaccuracies in the results, please visit: ', 'links': ['https://www.arin.net/resources/whois_reporting/index.html']}, {'title': 'Copyright Notice', 'description': 'Copyright 1997-2019, American Registry for Internet Numbers, Ltd.', 'links': None}], 'links': ['https://rdap.arin.net/registry/ip/64.56.83.0', 'https://whois.arin.net/rest/net/NET-64-56-83-0-1', 'https://rdap.arin.net/registry/ip/64.56.80.0/20'], 'events': [{'action': 'last changed', 'timestamp': '2011-08-02T08:10:00-04:00', 'actor': None}, {'action': 'registration', 'timestamp': '2011-08-02T08:10:00-04:00', 'actor': None}], 'raw': None, 'start_address': '64.56.83.0', 'end_address': '64.56.83.255', 'cidr': '64.56.83.0/24', 'ip_version': 'v4', 'type': None, 'name': 'NET-FLR-PSC-1', 'country': None, 'parent_handle': 'NET-64-56-80-0-1'}, 'entities': ['C02812677'], 'objects': {'C02812677': {'handle': 'C02812677', 'status': None, 'remarks': None, 'notices': None, 'links': ['https://rdap.arin.net/registry/entity/C02812677', 'https://whois.arin.net/rest/org/C02812677'], 'events': [{'action': 'last changed', 'timestamp': '2011-08-02T08:10:00-04:00', 'actor': None}, {'action': 'registration', 'timestamp': '2011-08-02T08:10:00-04:00', 'actor': None}], 'raw': None, 'roles': ['registrant'], 'contact': {'name': 'Polk State College', 'kind': 'org', 'address': [{'type': None, 'value': '999 Ave. H. NE\nWinter Haven\nFL\n33881\nUnited States'}], 'phone': None, 'email': None, 'role': None, 'title': None}, 'events_actor': None, 'entities': ['FLL-8']}}, 'raw': None}

# %%
train_m = pd.read_csv('Data/Train_Detections.csv')

# %%
train_m.head()
# Out:
#    Unnamed: 0  client          dst_ip  dst_port  epoch_time    label protocol  \
# 0           0       3         8.8.8.8        53  1546370065  Malware      UDP
# 1           1       2         8.8.8.8        53  1546607964  Malware      UDP
# 2           2       2  10.200.105.201        53  1545917481  Malware      UDP
# 3           3       2         8.8.8.8        53  1545386094  Malware      UDP
# 4           4       3  192.168.98.222        80  1546243671  Malware      TCP
#
#    received_bytes  sent_bytes           src_ip
# 0               0           0    192.168.37.10
# 1               0           0   192.168.186.37
# 2             456         164     10.195.74.11
# 3               0          70  192.168.143.103
# 4               0           0    192.168.37.10

# %%
def ip_internal_external(ip_addresses):
    results = {'ip':[], 'type':[], 'subtype':[]}
    for ip_address in ip_addresses:
        results['ip'].append(ip_address)
        splitted_ip = ip_address.split('.')
        if splitted_ip[0] == '127':
            results['type'].append('Loopback')
            results['subtype'].append('Loopback')
        elif int(splitted_ip[0]) >= 224 and int(splitted_ip[0]) <= 239:
            results['type'].append('Multicast')
            results['subtype'].append('Multicast')
        elif ip_address == '255.255.255.255':
            results['type'].append('Limited Broadcast')
            results['subtype'].append('Limited Broadcast')
        elif splitted_ip[0] == '10':
            results['type'].append('Internal')
            results['subtype'].append('Class A')
        elif splitted_ip[0] == '172' and int(splitted_ip[1]) >= 16 and int(splitted_ip[1]) <= 31:
            results['type'].append('Internal')
            results['subtype'].append('Class B')
        elif splitted_ip[0] == '192' and splitted_ip[1] == '168':
            results['type'].append('Internal')
            results['subtype'].append('Class C')
        elif splitted_ip[3] == '0':
            results['type'].append('Network space')
            results['subtype'].append('Network space')
        elif splitted_ip[3] == '255':
            results['type'].append('Broadcast address')
            results['subtype'].append('Broadcast address')
        else:
            results['type'].append('External')
            results['subtype'].append('External')
    
    return pd.DataFrame.from_dict(results)
            
ip_internal_external(['192.168.1.1', '20.10.30.40', '10.1.2.3', '172.25.30.8', '254.255.255.255',
                     '255.255.255.255', '230.28.30.21', '120.0.0.0', '127.5.6.7'])
# Out:
#                 ip               type            subtype
# 0      192.168.1.1           Internal            Class C
# 1      20.10.30.40           External           External
# 2         10.1.2.3           Internal            Class A
# 3      172.25.30.8           Internal            Class B
# 4  254.255.255.255  Broadcast address  Broadcast address
# 5  255.255.255.255  Limited Broadcast  Limited Broadcast
# 6     230.28.30.21          Multicast          Multicast
# 7        120.0.0.0      Network space      Network space
# 8        127.5.6.7           Loopback           Loopback

# %%
train_m = pd.read_csv('Data/ips.csv')

# %%
enriched_ip = ip_internal_external(train_m.IP.to_list())
enriched_ip
# Out:
#                    ip      type  subtype
# 0        10.197.88.33  Internal  Class A
# 1          10.0.11.69  Internal  Class A
# 2     192.168.174.137  Internal  Class C
# 3     192.168.190.183  Internal  Class C
# 4           10.0.11.2  Internal  Class A
# 5        10.196.88.30  Internal  Class A
# 6      10.197.208.101  Internal  Class A
# 7         10.0.11.156  Internal  Class A
# 8          10.0.11.67  Internal  Class A
# 9          10.0.11.62  Internal  Class A
# 10        10.0.11.120  Internal  Class A
# 11        10.0.11.162  Internal  Class A
# 12        10.0.11.170  Internal  Class A
# 13        10.0.11.168  Internal  Class A
# 14        10.0.11.100  Internal  Class A
# 15         10.0.11.86  Internal  Class A
# 16        10.0.11.139  Internal  Class A
# 17        10.0.11.106  Internal  Class A
# 18       10.196.86.72  Internal  Class A
# 19      10.196.144.39  Internal  Class A
# 20     192.168.192.91  Internal  Class C
# 21        10.0.11.176  Internal  Class A
# 22       10.127.13.47  Internal  Class A
# 23       10.196.88.23  Internal  Class A
# 24         10.0.11.75  Internal  Class A
# 25       10.197.86.23  Internal  Class A
# 26     10.196.254.150  Internal  Class A
# 27        10.0.11.154  Internal  Class A
# 28     10.197.208.108  Internal  Class A
# 29      10.200.46.102  Internal  Class A
# ...               ...       ...      ...
# 3324   192.168.178.48  Internal  Class C
# 3325   192.168.200.57  Internal  Class C
# 3326     10.197.88.15  Internal  Class A
# 3327     10.196.80.77  Internal  Class A
# 3328  192.168.174.221  Internal  Class C
# 3329      10.196.84.7  Internal  Class A
# 3330    10.197.90.125  Internal  Class A
# 3331   192.168.150.79  Internal  Class C
# 3332     10.195.208.5  Internal  Class A
# 3333   192.168.190.61  Internal  Class C
# 3334   192.168.200.24  Internal  Class C
# 3335   192.168.156.91  Internal  Class C
# 3336  192.168.179.227  Internal  Class C
# 3337   192.168.156.65  Internal  Class C
# 3338    10.197.206.22  Internal  Class A
# 3339    10.195.206.15  Internal  Class A
# 3340     10.196.88.39  Internal  Class A
# 3341    10.196.142.24  Internal  Class A
# 3342  192.168.192.116  Internal  Class C
# 3343   192.168.176.10  Internal  Class C
# 3344     10.197.88.40  Internal  Class A
# 3345     10.195.18.52  Internal  Class A
# 3346  192.168.162.186  Internal  Class C
# 3347   192.168.156.47  Internal  Class C
# 3348   192.168.162.60  Internal  Class C
# 3349   192.168.190.38  Internal  Class C
# 3350   192.168.198.11  Internal  Class C
# 3351    10.195.208.27  Internal  Class A
# 3352  192.168.157.177  Internal  Class C
# 3353  192.168.171.253  Internal  Class C
#
# [3354 rows x 3 columns]

# %%
enriched_ip.to_csv('Data/IPTypes.csv')

# %%
def ip_details(ip_addresses, suffix):
    for ip_address in ip_addresses:
        details = {'ip': ip_address}
        try:
            obj = IPWhois(ip_address)
            results = obj.lookup_whois()
            details[suffix+'asn'] = results['asn']
            
            if results['nets'][0]['country'] is not None:
                details[suffix+'country'] = results['nets'][0]['country']
            elif results['network']['asn_country_code'] is not None:
                details[suffix+'country'] = results['network']['asn_country_code']
            else:
                details[suffix+'country'] = 'Missing'
                
            

        except IPDefinedError:
            print('Internal')
            details[suffix+'country'] = 'Internal'
            details[suffix+'asn'] = 'Internal'
            
    
    
ip_details('8.8.8.8', 'abc')
# Out:
# None

# %%
enriched_ip[enriched_ip.type != 'Internal']
# Out:
#                    ip       type    subtype
# 36     200.75.192.252   External   External
# 57     165.203.37.103   External   External
# 81    199.112.224.171   External   External
# 90     200.75.192.250   External   External
# 100      64.56.83.238   External   External
# 108    191.234.217.13   External   External
# 130    183.54.157.216   External   External
# 201     191.17.26.118   External   External
# 244      43.49.231.76   External   External
# 312   138.232.226.187   External   External
# 328       87.7.13.157   External   External
# 336   190.105.247.250   External   External
# 369       91.119.63.4   External   External
# 387   226.233.119.247  Multicast  Multicast
# 411           7.1.1.1   External   External
# 507      77.6.167.142   External   External
# 510       29.55.58.46   External   External
# 514    204.108.66.226   External   External
# 551    135.204.19.217   External   External
# 553     188.89.65.228   External   External
# 569    125.28.204.237   External   External
# 598     207.93.106.99   External   External
# 606       84.31.94.93   External   External
# 612    214.46.117.190   External   External
# 655    204.108.66.227   External   External
# 676      202.52.43.51   External   External
# 683   201.154.181.182   External   External
# 704     67.219.11.151   External   External
# 731     88.102.25.244   External   External
# 780     43.49.231.203   External   External
# ...               ...        ...        ...
# 3077     202.52.84.54   External   External
# 3082       77.6.232.4   External   External
# 3085    202.52.43.105   External   External
# 3087    202.52.43.116   External   External
# 3096   183.190.176.99   External   External
# 3100     200.76.139.2   External   External
# 3104   129.182.83.112   External   External
# 3109      55.116.8.93   External   External
# 3113    83.96.153.189   External   External
# 3114    112.75.79.172   External   External
# 3116    202.52.43.127   External   External
# 3119    120.116.26.86   External   External
# 3121     75.192.2.137   External   External
# 3123     191.35.62.80   External   External
# 3124    200.29.32.132   External   External
# 3133    77.19.250.131   External   External
# 3141  145.162.106.181   External   External
# 3143        127.0.0.1   Loopback   Loopback
# 3144        127.0.0.2   Loopback   Loopback
# 3145        127.0.0.3   Loopback   Loopback
# 3146        127.0.0.4   Loopback   Loopback
# 3147        127.0.0.5   Loopback   Loopback
# 3149    101.172.68.56   External   External
# 3151  191.169.255.149   External   External
# 3178    72.240.205.34   External   External
# 3224   191.220.70.162   External   External
# 3257    88.102.21.215   External   External
# 3293   72.203.212.222   External   External
# 3302   95.238.154.247   External   External
# 3317    125.23.18.143   External   External
#
# [364 rows x 3 columns]

# %%
from multiprocessing.dummy import Pool as ThreadPool 
import json

def ip_details(ip_address):
    try:
        obj = IPWhois(ip_address)
        request = obj.lookup_whois()
        return({'ip':ip_address, 'json':json.dumps(request)})
    except Exception as e:
        print(e)
        return ({'ip':ip_address, 'json':None})

def ip_list_details(ip_addresses):
    pool = ThreadPool(100)
    results = pool.map(ip_details, ip_addresses)
            
    return pd.DataFrame.from_dict(results)

ip_list_details(['200.75.192.252','125.23.18.143', '127.168.1.1'])
# Out:
# IPv4 address 127.168.1.1 is already defined as Loopback via RFC 1122, Section 3.2.1.3.
#                ip                                               json
# 0  200.75.192.252  {"nir": null, "asn_registry": "lacnic", "asn":...
# 1   125.23.18.143  {"nir": null, "asn_registry": "apnic", "asn": ...
# 2     127.168.1.1                                               None

# %%
df_whois = ip_list_details(enriched_ip[enriched_ip.type != 'Internal'].ip.to_list())
# Out:
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/asn.py:407: UserWarning: IPASN._parse_fields_http() has been deprecated and will be removed. You should now use IPASN.parse_fields_http().
#   warn('IPASN._parse_fields_http() has been deprecated and will be '
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/whois.py:424: UserWarning: Whois._get_nets_arin() has been deprecated and will be removed. You should now use Whois.get_nets_arin().
#   warn('Whois._get_nets_arin() has been deprecated and will be '
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/asn.py:302: UserWarning: IPASN._parse_fields_whois() has been deprecated and will be removed. You should now use IPASN.parse_fields_whois().
#   warn('IPASN._parse_fields_whois() has been deprecated and will be '
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/nir.py:368: UserWarning: NIRWhois._get_nets_jpnic() has been deprecated and will be removed. You should now use NIRWhois.get_nets_jpnic().
#   warn('NIRWhois._get_nets_jpnic() has been deprecated and will be '
# IPv4 address 226.233.119.247 is already defined as Multicast via RFC 3171.
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/nir.py:295: UserWarning: NIRWhois._parse_fields() has been deprecated and will be removed. You should now use NIRWhois.parse_fields().
#   warn('NIRWhois._parse_fields() has been deprecated and will be '
# /Users/jeremybensoussan/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/nir.py:500: UserWarning: NIRWhois._get_contact() has been deprecated and will be removed. You should now use NIRWhois.get_contact().
#   warn('NIRWhois._get_contact() has been deprecated and will be '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-a92e929a9c2a> in <module>
# ----> 1 df_whois = ip_details(enriched_ip[enriched_ip.type != 'Internal'].ip.to_list())
#
# <ipython-input-80-565e1a6821a7> in ip_details(ip_addresses)
#       5         try:
#       6             obj = IPWhois(ip_address)
# ----> 7             request = obj.lookup_whois()
#       8             results['ip'].append(ip_address)
#       9             results['json'].append(json.dumps(request))
#
# ~/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/ipwhois.py in lookup_whois(self, inc_raw, retry_count, get_referral, extra_blacklist, ignore_referral_errors, field_list, asn_alts, extra_org_map, inc_nir, nir_field_list, asn_methods, get_asn_description)
#     197                     nir=nir, inc_raw=inc_raw, retry_count=retry_count,
#     198                     response=None,
# --> 199                     field_list=nir_field_list, is_offline=False
#     200                 )
#     201
#
# ~/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/nir.py in lookup(self, nir, inc_raw, retry_count, response, field_list, is_offline)
#     665                                     nir=nir,
#     666                                     retry_count=retry_count,
# --> 667                                     dt_format=dt_format
#     668                                 )
#     669                                 global_contacts[contact] = (
#
# ~/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/nir.py in _get_contact(self, *args, **kwargs)
#     500         warn('NIRWhois._get_contact() has been deprecated and will be '
#     501              'removed. You should now use NIRWhois.get_contact().')
# --> 502         return self.get_contact(*args, **kwargs)
#     503
#     504     def lookup(self, nir=None, inc_raw=False, retry_count=3, response=None,
#
# ~/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/nir.py in get_contact(self, response, nir, handle, retry_count, dt_format)
#     481                 retry_count=retry_count,
#     482                 headers=NIR_WHOIS[nir]['request_headers'],
# --> 483                 request_type=NIR_WHOIS[nir]['request_type']
#     484             )
#     485
#
# ~/anaconda3/envs/ITC/lib/python3.6/site-packages/ipwhois/net.py in get_http_raw(self, url, retry_count, headers, request_type, form_data)
#     910             except TypeError:  # pragma: no cover
#     911                 conn = Request(url=url, data=enc_form_data, headers=headers)
# --> 912             data = self.opener.open(conn, timeout=self.timeout)
#     913
#     914             try:
#
# ~/anaconda3/envs/ITC/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda3/envs/ITC/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda3/envs/ITC/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/envs/ITC/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/ITC/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# ~/anaconda3/envs/ITC/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/anaconda3/envs/ITC/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# ~/anaconda3/envs/ITC/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda3/envs/ITC/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~/anaconda3/envs/ITC/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# ~/anaconda3/envs/ITC/lib/python3.6/http/client.py in connect(self)
#     934         """Connect to the host and port specified in __init__."""
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     938
#
# ~/anaconda3/envs/ITC/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#     715             err = None
#
# KeyboardInterrupt:

# %%
df_whois
# Out:
#                ip                                               json
# 0  200.75.192.252  {"nir": null, "asn_registry": "lacnic", "asn":...
# 1   125.23.18.143  {"nir": null, "asn_registry": "apnic", "asn": ...

# %%
df_whois.to_csv('Data/ExternalIPWhois.csv')

# %%
df_whois_reloaded = pd.read_csv('Data/ExternalIPWhois.csv')

# %%
json.loads(df_whois_reloaded.iloc[0].json)
# Out:
# {'nir': None,
#  'asn_registry': 'lacnic',
#  'asn': '18809',
#  'asn_cidr': '200.75.192.0/22',
#  'asn_country_code': 'PA',
#  'asn_date': '2001-10-25',
#  'asn_description': 'Cable Onda, PA',
#  'query': '200.75.192.252',
#  'nets': [{'cidr': '200.75.192.0/19',
#    'name': None,
#    'handle': 'CAO',
#    'range': '200.75.192/19',
#    'description': 'Cable Onda',
#    'country': 'PA',
#    'state': None,
#    'city': None,
#    'address': None,
#    'postal_code': None,
#    'emails': ['ipadmin@CABLEONDA.NET'],
#    'created': '20011025',
#    'updated': '20020528'}],
#  'raw': None,
#  'referral': None,
#  'raw_referral': None}
